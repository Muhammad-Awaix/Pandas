# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df['survived'].unique()
# Out:
# array([0, 1])

# %%
df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ### Most of the people die

# %%
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### Most of the passengers are male

# %%
df.groupby('sex')['survived'].sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
sns.scatterplot(data=df, x='class', y='fare', hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# ### 1st class passengers pay more than 2nd and 3rd class passengers

# %%
sns.countplot(data=df, x='class', hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ### Male are dominant in every class

# %%
sns.barplot(data=df, y='survived', x='sex', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %% [markdown]
# ### Survival rate of 1st class passengers is higher than 2nd and 3rd class passengers females are survived more then men

# %%
print(df['age'].min())
print(df['age'].max())
print(df['age'].mean())
# Out:
# 0.42
# 80.0
# 29.69911764705882

# %%
print(df['fare'].min())
print(df['fare'].max())
print(df['fare'].mean())
# Out:
# 0.0
# 512.3292
# 32.204207968574636

# %%
df['fare'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(data=df, x='age',y='fare', hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %% [markdown]
# ## You can also change the color of the bars by using the `palettle` parameter
